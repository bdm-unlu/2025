# %% [markdown]
# # Clase 2: Guía de preprocesamiento [Parte 2]
#
# Base de datos masivas (11088) - Curso 2024
#
# Esta guia contiene ejemplos con Python y librerias como Pandas, Numpy, etc. para realizar tareas de la etapa de preprocesamiento y transformación de datos.
# En esta segunda parte nos vamos a enfocar en:
#
#   1. Manejo de datos faltantes: Imputación puntual (o simple) y modelos implícitos.
#   2. Reducción de dimensionalidad.

# %%
# Librerias
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import zscore

from sklearn.impute import KNNImputer

# %% [markdown]
# ## Datos Faltantes

# %%
# Datos Iris
iris = pd.read_csv('https://raw.githubusercontent.com/bdm-unlu/2024/main/TPs/TP01/iris_faltantes.csv')

iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2        NaN
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          NaN           1.5          0.2     setosa
# 4             NaN          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           NaN          NaN           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           NaN          3.0           5.2          2.0        NaN
# 148           6.2          3.4           5.4          2.3        NaN
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.describe( include= "all")
# Out:
#         Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# count     135.000000   135.000000    135.000000   135.000000         135
# unique           NaN          NaN           NaN          NaN           3
# top              NaN          NaN           NaN          NaN  versicolor
# freq             NaN          NaN           NaN          NaN          47
# mean        5.829630     3.040741      3.717778     1.212593         NaN
# std         0.843153     0.428865      1.757027     0.774060         NaN
# min         4.300000     2.200000      1.000000     0.100000         NaN
# 25%         5.100000     2.800000      1.500000     0.300000         NaN
# 50%         5.800000     3.000000      4.300000     1.300000         NaN
# 75%         6.400000     3.300000      5.100000     1.800000         NaN
# max         7.900000     4.400000      6.900000     2.500000         NaN

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in /usr/local/lib/python3.12/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from missingno) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from missingno) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from missingno) (1.16.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)

# %%
import missingno as msno

msno.matrix(iris)
# Out:
# <Axes: >

# %%
msno.bar(iris)
# Out:
# <Axes: >

# %%
msno.heatmap(iris) #correlacion entre los faltantes
# Out:
# <Axes: >

# %% [markdown]
# ## Imputación simple
#
# Para la imputación puntual podemos usar una medida de tendencia central como la media, mediana o la moda.

# %%
variables_num = ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']
variables_cat = ['Species']

# %%
medias = iris[variables_num].mean()
medias
# Out:
# Sepal.Length    5.829630
# Sepal.Width     3.040741
# Petal.Length    3.717778
# Petal.Width     1.212593
# dtype: float64

# %%
medias.values[0]
# Out:
# np.float64(5.82962962962963)

# %%
iris_med = iris.copy()
for i, col in enumerate(variables_num):
  iris_med[col] = iris_med[col].fillna(medias.values[i])

iris_med.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.829630     3.040741      3.717778     1.212593
# std        0.799587     0.406705      1.666241     0.734064
# min        4.300000     2.200000      1.000000     0.100000
# 25%        5.125000     2.800000      1.600000     0.400000
# 50%        5.829630     3.000000      4.000000     1.300000
# 75%        6.300000     3.200000      5.000000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2        NaN
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          NaN           1.5          0.2     setosa
# 4             NaN          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           NaN          NaN           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           NaN          3.0           5.2          2.0        NaN
# 148           6.2          3.4           5.4          2.3        NaN
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
moda = iris[variables_cat].mode()
moda
# Out:
#       Species
# 0  versicolor

# %% [markdown]
# Imputamos con la moda la columna _Species_
#
# <img src="https://i.pinimg.com/736x/b3/8a/a5/b38aa506b099dd955dad165132a5ff3c.jpg" width="300">

# %%
for i, col in enumerate(variables_cat):
   iris_med[col] = iris_med[col].fillna(moda.values[i][0])
iris_med.describe(include="all")
# Out:
#         Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# count     150.000000   150.000000    150.000000   150.000000         150
# unique           NaN          NaN           NaN          NaN           3
# top              NaN          NaN           NaN          NaN  versicolor
# freq             NaN          NaN           NaN          NaN          62
# mean        5.829630     3.040741      3.717778     1.212593         NaN
# std         0.799587     0.406705      1.666241     0.734064         NaN
# min         4.300000     2.200000      1.000000     0.100000         NaN
# 25%         5.125000     2.800000      1.600000     0.400000         NaN
# 50%         5.829630     3.000000      4.000000     1.300000         NaN
# 75%         6.300000     3.200000      5.000000     1.800000         NaN
# max         7.900000     4.400000      6.900000     2.500000         NaN

# %% [markdown]
# **QUIZ 1**:  Verificar con el dataset original cómo resultaron esas imputaciones. ¿Cómo harian esa verificación con lo visto hasta ahora en el curso?
# El dataset está disponible [aquí](https://raw.githubusercontent.com/bdm-unlu/2021/main/dockers/r/data/iris.csv). 👁 el separador es el pipe (|)

# %% [markdown]
# ## Imputaciones con modelos implícitos
#
#
#
# *   Cold Deck 🧊
# *   Hot Deck 🔥

# %%
# Hot Deck: Es por vecinos mas cercanos
HotDeck = KNNImputer(n_neighbors=3, weights="uniform")

# %%
iris_hd = HotDeck.fit_transform(iris[variables_num])
iris_hd = pd.DataFrame(iris_hd, columns=variables_num)
iris_hd
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0        5.100000     3.500000           1.4          0.2
# 1        4.900000     3.000000           1.4          0.2
# 2        4.700000     3.200000           1.3          0.2
# 3        4.600000     3.400000           1.5          0.2
# 4        5.066667     3.600000           1.4          0.2
# ..            ...          ...           ...          ...
# 145      6.300000     3.133333           5.2          2.3
# 146      6.300000     2.500000           5.0          1.9
# 147      6.866667     3.000000           5.2          2.0
# 148      6.200000     3.400000           5.4          2.3
# 149      5.900000     3.000000           5.1          1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
# Encodeamos las categóricas
cat2num = LabelEncoder().fit([np.nan,'setosa', 'versicolor', 'virginica'])
iris["SpeciesN"]=cat2num.transform(iris.Species)
iris.loc[iris['SpeciesN']==0, 'SpeciesN'] = np.nan
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  SpeciesN
# 0             5.1          3.5           1.4          0.2        NaN       NaN
# 1             4.9          3.0           1.4          0.2     setosa       1.0
# 2             4.7          3.2           1.3          0.2     setosa       1.0
# 3             4.6          NaN           1.5          0.2     setosa       1.0
# 4             NaN          3.6           1.4          0.2     setosa       1.0
# ..            ...          ...           ...          ...        ...       ...
# 145           NaN          NaN           5.2          2.3  virginica       3.0
# 146           6.3          2.5           5.0          1.9  virginica       3.0
# 147           NaN          3.0           5.2          2.0        NaN       NaN
# 148           6.2          3.4           5.4          2.3        NaN       NaN
# 149           5.9          3.0           5.1          1.8  virginica       3.0
#
# [150 rows x 6 columns]

# %%
variables_num_2 = ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']
variables_num_2.append('SpeciesN')
iris_hd = HotDeck.fit_transform(iris[variables_num_2])
iris_hd = pd.DataFrame(iris_hd, columns=variables_num_2)
iris_hd
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  SpeciesN
# 0        5.100000     3.500000           1.4          0.2  1.000000
# 1        4.900000     3.000000           1.4          0.2  1.000000
# 2        4.700000     3.200000           1.3          0.2  1.000000
# 3        4.600000     3.400000           1.5          0.2  1.000000
# 4        5.166667     3.600000           1.4          0.2  1.000000
# ..            ...          ...           ...          ...       ...
# 145      6.300000     3.133333           5.2          2.3  3.000000
# 146      6.300000     2.500000           5.0          1.9  3.000000
# 147      6.866667     3.000000           5.2          2.0  2.666667
# 148      6.200000     3.400000           5.4          2.3  3.000000
# 149      5.900000     3.000000           5.1          1.8  3.000000
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Imputación utilizando regresiones

# %%
from sklearn.linear_model import LinearRegression

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  SpeciesN
# 0             5.1          3.5           1.4          0.2        NaN       NaN
# 1             4.9          3.0           1.4          0.2     setosa       1.0
# 2             4.7          3.2           1.3          0.2     setosa       1.0
# 3             4.6          NaN           1.5          0.2     setosa       1.0
# 4             NaN          3.6           1.4          0.2     setosa       1.0
# ..            ...          ...           ...          ...        ...       ...
# 145           NaN          NaN           5.2          2.3  virginica       3.0
# 146           6.3          2.5           5.0          1.9  virginica       3.0
# 147           NaN          3.0           5.2          2.0        NaN       NaN
# 148           6.2          3.4           5.4          2.3        NaN       NaN
# 149           5.9          3.0           5.1          1.8  virginica       3.0
#
# [150 rows x 6 columns]

# %%
# Varables independientes
ind = ['Petal.Length']

# Variable dependiente (la que vamos a estimar)
dep = ['Sepal.Length']

# Eliminamos todos los NAs
iris_sinNA = iris.dropna()
X = iris_sinNA[ind]
y = iris_sinNA[dep]

# Ajuste del modelo de regresión
reg = LinearRegression().fit(X, y)
print("R²:",reg.score(X, y))
print("Coef:",reg.coef_)
# Out:
# R²: 0.7516901272100955
# Coef: [[0.40584852]]

# %%
reg.predict(iris[ind].fillna(iris[ind].median()))
# Out:
# array([[4.89692648],
#        [4.89692648],
#        [4.85634163],
#        [4.93751133],
#        [4.89692648],
#        [5.01868104],
#        [4.89692648],
#        [4.93751133],
#        [4.89692648],
#        [4.93751133],
#        [4.93751133],
#        [6.07388719],
#        [4.89692648],
#        [6.07388719],
#        [4.81575678],
#        [4.93751133],
#        [4.85634163],
#        [4.89692648],
#        [5.01868104],
#        [4.93751133],
#        [5.01868104],
#        [4.93751133],
#        [4.73458708],
#        [5.01868104],
#        [5.09985074],
#        [4.97809619],
#        [4.97809619],
#        [4.93751133],
#        [4.89692648],
#        [4.97809619],
#        [4.97809619],
#        [4.93751133],
#        [6.07388719],
#        [4.89692648],
#        [4.93751133],
#        [4.81575678],
#        [4.85634163],
#        [4.89692648],
#        [4.85634163],
#        [4.93751133],
#        [4.85634163],
#        [4.85634163],
#        [4.85634163],
#        [6.07388719],
#        [5.09985074],
#        [4.89692648],
#        [4.97809619],
#        [4.89692648],
#        [4.93751133],
#        [4.89692648],
#        [6.23622659],
#        [6.15505689],
#        [6.3173963 ],
#        [5.95213263],
#        [6.19564174],
#        [6.15505689],
#        [6.23622659],
#        [5.66803867],
#        [6.19564174],
#        [5.91154778],
#        [5.74920837],
#        [6.03330233],
#        [5.95213263],
#        [6.23622659],
#        [5.78979322],
#        [6.11447204],
#        [6.15505689],
#        [6.07388719],
#        [6.15505689],
#        [5.91154778],
#        [6.27681145],
#        [5.95213263],
#        [6.3173963 ],
#        [6.23622659],
#        [6.07388719],
#        [6.11447204],
#        [6.27681145],
#        [6.35798115],
#        [6.15505689],
#        [5.74920837],
#        [6.07388719],
#        [5.83037808],
#        [5.91154778],
#        [6.398566  ],
#        [6.15505689],
#        [6.15505689],
#        [6.07388719],
#        [6.11447204],
#        [5.99271748],
#        [5.95213263],
#        [6.07388719],
#        [6.19564174],
#        [5.95213263],
#        [5.66803867],
#        [6.03330233],
#        [6.03330233],
#        [6.03330233],
#        [6.07388719],
#        [5.54628411],
#        [5.99271748],
#        [6.76382967],
#        [6.398566  ],
#        [6.07388719],
#        [6.60149026],
#        [6.68265996],
#        [6.07388719],
#        [6.07388719],
#        [6.07388719],
#        [6.68265996],
#        [6.80441452],
#        [6.398566  ],
#        [6.4797357 ],
#        [6.56090541],
#        [6.35798115],
#        [6.398566  ],
#        [6.4797357 ],
#        [6.56090541],
#        [7.04792363],
#        [7.12909333],
#        [6.35798115],
#        [6.64207511],
#        [6.3173963 ],
#        [7.04792363],
#        [6.3173963 ],
#        [6.64207511],
#        [6.76382967],
#        [6.27681145],
#        [6.3173963 ],
#        [6.60149026],
#        [6.07388719],
#        [6.80441452],
#        [6.92616908],
#        [6.60149026],
#        [6.398566  ],
#        [6.60149026],
#        [6.80441452],
#        [6.60149026],
#        [6.56090541],
#        [6.27681145],
#        [6.52032056],
#        [6.07388719],
#        [6.398566  ],
#        [6.398566  ],
#        [6.72324482],
#        [6.64207511],
#        [6.43915085],
#        [6.35798115],
#        [6.43915085],
#        [6.52032056],
#        [6.398566  ]])

# %%
# Hacemos la predicción con el modelo de regresión lineal multiple
iris['Sepal.Length_RegLin'] = reg.predict(iris[ind].fillna(iris[ind].median()))

# Asignamos los valores originales
iris['Sepal.Length_IMP'] = iris['Sepal.Length']

# %%
# Rellenamos los NAs con los valores obtenidos en la regresión
iris.loc[np.isnan(iris['Sepal.Length_IMP']),'Sepal.Length_IMP'] = iris.loc[np.isnan(iris['Sepal.Length_IMP']), 'Sepal.Length_RegLin']

# %%
iris["Sepal.Length_MED"] = iris_med["Sepal.Length"] # Agregamos la media

# %%
iris_ori = pd.read_csv("https://raw.githubusercontent.com/bdm-unlu/2021/main/dockers/r/data/iris.csv", delimiter="|")
iris['Sepal.Length_ORI'] = iris_ori["Sepal.Length"]

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2        NaN
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          NaN           1.5          0.2     setosa
# 4             NaN          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           NaN          NaN           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           NaN          3.0           5.2          2.0        NaN
# 148           6.2          3.4           5.4          2.3        NaN
# 149           5.9          3.0           5.1          1.8  virginica
#
#      SpeciesN  Sepal.Length_RegLin  Sepal.Length_IMP  Sepal.Length_MED  \
# 0         NaN             4.896926          5.100000           5.10000
# 1         1.0             4.896926          4.900000           4.90000
# 2         1.0             4.856342          4.700000           4.70000
# 3         1.0             4.937511          4.600000           4.60000
# 4         1.0             4.896926          4.896926           5.82963
# ..        ...                  ...               ...               ...
# 145       3.0             6.439151          6.439151           5.82963
# 146       3.0             6.357981          6.300000           6.30000
# 147       NaN             6.439151          6.439151           5.82963
# 148       NaN             6.520321          6.200000           6.20000
# 149       3.0             6.398566          5.900000           5.90000
#
#      Sepal.Length_ORI
# 0                 5.1
# 1                 4.9
# 2                 4.7
# 3                 4.6
# 4                 5.0
# ..                ...
# 145               6.7
# 146               6.3
# 147               6.5
# 148               6.2
# 149               5.9
#
# [150 rows x 10 columns]

# %%
iris[["Sepal.Length_ORI", "Sepal.Length_IMP", "Sepal.Length_MED"]].corr()
# Out:
#                   Sepal.Length_ORI  Sepal.Length_IMP  Sepal.Length_MED
# Sepal.Length_ORI          1.000000          0.992637          0.965607
# Sepal.Length_IMP          0.992637          1.000000          0.977714
# Sepal.Length_MED          0.965607          0.977714          1.000000

# %%
import seaborn as sns
sns.pairplot(data = iris, vars=["Sepal.Length_ORI", "Sepal.Length_IMP", "Sepal.Length_MED"] )
plt.show()

# %% [markdown]
# ## Reducción de dimensionalidad

# %%
data = pd.read_csv("https://raw.githubusercontent.com/bdm-unlu/2021/main/dockers/r/data/iris.csv", delimiter="|")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Escalamos las variables numéricas
variables_num = ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']
x = StandardScaler().fit_transform(data[variables_num])

# %%
# Aplicamos la descomposición en CP

n_cp = len(variables_num) # Definimos la cantidad de CP
columns = [f"CP{i+1}" for i in range(n_cp)]

pca = PCA(n_components=n_cp)

principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = columns)
principalDf
# Out:
#           CP1       CP2       CP3       CP4
# 0   -2.264703  0.480027  0.127706 -0.024168
# 1   -2.080961 -0.674134  0.234609 -0.103007
# 2   -2.364229 -0.341908 -0.044201 -0.028377
# 3   -2.299384 -0.597395 -0.091290  0.065956
# 4   -2.389842  0.646835 -0.015738  0.035923
# ..        ...       ...       ...       ...
# 145  1.870503  0.386966 -0.256274 -0.389257
# 146  1.564580 -0.896687  0.026371 -0.220192
# 147  1.521170  0.269069 -0.180178 -0.119171
# 148  1.372788  1.011254 -0.933395 -0.026129
# 149  0.960656 -0.024332 -0.528249  0.163078
#
# [150 rows x 4 columns]

# %%
# Varianza explicada
pca.explained_variance_ratio_
# Out:
# array([0.72962445, 0.22850762, 0.03668922, 0.00517871])

# %%
# Varianza explicada acumulada
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.72962445, 0.95813207, 0.99482129, 1.        ])

# %%
# Generar la matriz de loadings (correlación entre las componentes y las variables originales)
pd.DataFrame(pca.components_, columns=variables_num)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0      0.521066    -0.269347      0.580413     0.564857
# 1      0.377418     0.923296      0.024492     0.066942
# 2      0.719566    -0.244382     -0.142126    -0.634273
# 3     -0.261286     0.123510      0.801449    -0.523597

# %%
principalDf["Species"] = data.Species
principalDf
# Out:
#           CP1       CP2       CP3       CP4    Species
# 0   -2.264703  0.480027  0.127706 -0.024168     setosa
# 1   -2.080961 -0.674134  0.234609 -0.103007     setosa
# 2   -2.364229 -0.341908 -0.044201 -0.028377     setosa
# 3   -2.299384 -0.597395 -0.091290  0.065956     setosa
# 4   -2.389842  0.646835 -0.015738  0.035923     setosa
# ..        ...       ...       ...       ...        ...
# 145  1.870503  0.386966 -0.256274 -0.389257  virginica
# 146  1.564580 -0.896687  0.026371 -0.220192  virginica
# 147  1.521170  0.269069 -0.180178 -0.119171  virginica
# 148  1.372788  1.011254 -0.933395 -0.026129  virginica
# 149  0.960656 -0.024332 -0.528249  0.163078  virginica
#
# [150 rows x 5 columns]

# %%
labels = principalDf["Species"].unique().tolist()
labels
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)
eje1 = "CP1"
eje2 = "CP2"
ax.set_xlabel(eje1, fontsize = 15)
ax.set_ylabel(eje2, fontsize = 15)
ax.set_title('PCA', fontsize = 20)

targets = [i for i in labels]
colors = ['#e41a1c','#377eb8','#4daf4a']
for target, color in zip(targets,colors):
    indicesToKeep = principalDf['Species'] == target
    ax.scatter(principalDf.loc[indicesToKeep, eje1]
               , principalDf.loc[indicesToKeep, eje2]
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)
eje1 = "CP1"
eje2 = "CP4"
ax.set_xlabel(eje1, fontsize = 15)
ax.set_ylabel(eje2, fontsize = 15)
ax.set_title('PCA', fontsize = 20)

targets = [i for i in labels]
colors = ['#e41a1c','#377eb8','#4daf4a']
for target, color in zip(targets,colors):
    indicesToKeep = principalDf['Species'] == target
    ax.scatter(principalDf.loc[indicesToKeep, eje1]
               , principalDf.loc[indicesToKeep, eje2]
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

coeff = np.transpose(pca.components_[0:2, :])
n = coeff.shape[0]
for i in range(n):
    ax.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
    plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, variables_num[i], color = 'g', ha = 'center', va = 'center')

print(pca.components_)
print(coeff)
# Out:
# [[ 0.52106591 -0.26934744  0.5804131   0.56485654]
#  [ 0.37741762  0.92329566  0.02449161  0.06694199]
#  [ 0.71956635 -0.24438178 -0.14212637 -0.63427274]
#  [-0.26128628  0.12350962  0.80144925 -0.52359713]]
# [[ 0.52106591  0.37741762]
#  [-0.26934744  0.92329566]
#  [ 0.5804131   0.02449161]
#  [ 0.56485654  0.06694199]]

# %%
def biplot(score,coeff,y,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley, c = y)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
    plt.xlim(-1,1)
    plt.ylim(-1,1)
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

# %%
cols = {"versicolor": "blue", "virginica": "green", "setosa": "red"}
y = list(map(cols.get, principalDf['Species']))
biplot(principalComponents[:,0:2],np.transpose(pca.components_[0:2, :]),y, variables_num)
plt.show()

# %%
# !pip install pca
# Out:
# Requirement already satisfied: pca in /usr/local/lib/python3.12/dist-packages (2.10.0)
# Requirement already satisfied: datazets in /usr/local/lib/python3.12/dist-packages (from pca) (1.1.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from pca) (0.14.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pca) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pca) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pca) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pca) (1.16.1)
# Requirement already satisfied: colourmap>=1.1.19 in /usr/local/lib/python3.12/dist-packages (from pca) (1.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pca) (2.2.2)
# Requirement already satisfied: scatterd>=1.3.7 in /usr/local/lib/python3.12/dist-packages (from pca) (1.4.1)
# Requirement already satisfied: adjusttext in /usr/local/lib/python3.12/dist-packages (from pca) (1.3.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from scatterd>=1.3.7->pca) (0.13.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from datazets->pca) (2.32.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pca) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pca) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pca) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pca) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pca) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->pca) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pca) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->datazets->pca) (2025.8.3)

# %%
#!pip install pca
from pca import pca as pca2

from sklearn.datasets import load_iris
iris = load_iris()
X = pd.DataFrame(data=StandardScaler().fit_transform(iris.data),
                 columns=iris.feature_names)
X.columns = ["sepal_length", "sepal_width", "petal_length", "petal_width"]
y = pd.Categorical.from_codes(iris.target,
                              iris.target_names)

model = pca2(n_components=4)

results = model.fit_transform(X=X, row_labels=y)

fig, ax = model.plot(figsize=(14, 8))
fig, ax = model.scatter(figsize=(14, 8))

#biplot
fig, ax = model.biplot(n_feat=4, figsize=(14, 8))
# Out:
# [27-08-2025 23:07:58] [pca.pca] [INFO] Extracting column labels from dataframe.
# [27-08-2025 23:07:58] [pca.pca] [INFO] The PCA reduction is performed on the 4 columns of the input dataframe.
# [27-08-2025 23:07:58] [pca.pca] [INFO] Fit using PCA.
# [27-08-2025 23:07:58] [pca.pca] [INFO] Compute loadings and PCs.
# [27-08-2025 23:07:58] [pca.pca] [INFO] Compute explained variance.
# [27-08-2025 23:07:58] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[4]
# [27-08-2025 23:07:58] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [27-08-2025 23:07:58] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]
# [27-08-2025 23:07:59] [scatterd.scatterd] [INFO] Create scatterplot
# [27-08-2025 23:07:59] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [27-08-2025 23:07:59] [scatterd.scatterd] [INFO] Create scatterplot
